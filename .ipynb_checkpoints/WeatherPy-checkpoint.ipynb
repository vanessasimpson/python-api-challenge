# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# %%
# Output File (CSV)
output_data_file = pd.read_csv('cities.csv')
output_data_file.dropna(inplace = True) 
output_data_file.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=0753a7ffef79182f8913727b7ab6363a&units=imperial&q='

# %%
record_count = 1
city_weather_data = []
print('Beginning Data Retrieval')
print('--------------------------')
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        city_name = response['name']
        city_country=response['sys']['country']
        city_lat = response['coord']['lat']
        city_lon = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_cloudiness = response['clouds']['all']
        city_wind_speed = response['wind']['speed']
        city_date = response['dt']
      
        
        city_weather_data.append({'City':city_name, 
                          'Country': city_country, 
                          'Latitude': city_lat, 
                          'Longitude': city_lon,
                          'Max Temperature': city_max_temp,
                          'Humidity': city_humidity, 
                          'Cloudiness': city_cloudiness, 
                          'Wind Speed': city_wind_speed,
                          'Date': city_date})
        
        
        print(f'Processing Record {record_count}| {city}')
        record_count+= 1
    except:
        print(f'City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1| mataura
# Processing Record 2| daru
# Processing Record 3| ponta do sol
# Processing Record 4| ushuaia
# Processing Record 5| new norfolk
# Processing Record 6| georgetown
# Processing Record 7| tasiilaq
# City not found. Skipping...
# Processing Record 8| hobart
# City not found. Skipping...
# Processing Record 9| port elizabeth
# Processing Record 10| pevek
# Processing Record 11| sabang
# Processing Record 12| medicine hat
# Processing Record 13| muravlenko
# Processing Record 14| te anau
# Processing Record 15| atuona
# Processing Record 16| vaini
# Processing Record 17| ahipara
# Processing Record 18| keflavik
# Processing Record 19| pangody
# Processing Record 20| voh
# Processing Record 21| bambous virieux
# Processing Record 22| longyearbyen
# Processing Record 23| semey
# Processing Record 24| kruisfontein
# Processing Record 25| dikson
# Processing Record 26| lompoc
# Processing Record 27| qandala
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
output_data_file.to_csv (r'C:\Users\vwsim\OneDrive\Desktop\python-api-challenge\dataframe.csv', index = False, header=True)

# %%
cities_df = pd.DataFrame(city_weather_data)
cities_df.head()
# Out:
#            City Country  Latitude  Longitude  Max Temperature  Humidity  \
# 0       Mataura      NZ    -46.19     168.86            53.58        82
# 1          Daru      PG     -9.08     143.21            80.26        60
# 2  Ponta do Sol      PT     32.67     -17.10            71.60        78
# 3       Ushuaia      AR    -54.80     -68.30            32.00        90
# 4   New Norfolk      AU    -42.78     147.06            53.01        80
#
#    Cloudiness  Wind Speed        Date
# 0          93        1.21  1597804350
# 1           1        9.22  1597804351
# 2          20        0.96  1597804351
# 3          40        8.05  1597804282
# 4          35        1.99  1597804352

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_index = cities_df[cities_df['Humidity'] > 100].index
humidity_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
new_city_data = cities_df.drop(humidity_index,inplace=False)
new_city_data.head()
# Out:
#            City Country  Latitude  Longitude  Max Temperature  Humidity  \
# 0       Mataura      NZ    -46.19     168.86            53.58        82
# 1          Daru      PG     -9.08     143.21            80.26        60
# 2  Ponta do Sol      PT     32.67     -17.10            71.60        78
# 3       Ushuaia      AR    -54.80     -68.30            32.00        90
# 4   New Norfolk      AU    -42.78     147.06            53.01        80
#
#    Cloudiness  Wind Speed        Date
# 0          93        1.21  1597804350
# 1           1        9.22  1597804351
# 2          20        0.96  1597804351
# 3          40        8.05  1597804282
# 4          35        1.99  1597804352

# %%
# Extract relevant fields from the data frame
new_city_data.describe()

# Export the City_Data into a csv
new_city_data.to_csv(r'C:\Users\vwsim\OneDrive\Desktop\python-api-challenge\dataframe.csv', index = False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
new_city_data['Date'] = new_city_data['Date'].astype('datetime64[ns]')

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
new_city_data.plot(kind='scatter', x='Latitude', y='Max Temperature', c='green')
plt.title('City Latitude vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('lat_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
new_city_data.plot(kind='scatter', x='Latitude', y='Humidity', c='blue')
plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('lat_humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
new_city_data.plot(kind='scatter', x='Latitude', y='Cloudiness', c='purple')
plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('lat_cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
new_city_data.plot(kind='scatter', x='Latitude', y='Wind Speed', c='purple')
plt.title('City Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('lat_wind.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression_plot(df,title_name,y_column_name,y_label,file_name,xy):
    x_values = df['Latitude']
    y_values = df[y_column_name]
    (slope,intercept,rvalue,pvalue,stderr) = linregress(x_values,y_values)
    regression_values = x_values * slope + intercept
    line_equation = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regression_values,'r-')
    plt.annotate(line_equation,xy,fontsize=15,color='red')
    plt.xlabel('Latiude')
    plt.ylabel(y_label)  
    plt.title(title_name)
    
    print(f'The r-squared is: {rvalue}')
    plt.savefig(file_name)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = new_city_data.loc[new_city_data['Latitude'] >= 0]
southern_hemisphere_df = new_city_data.loc[new_city_data['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_hemisphere_df,
                       'Northern Hemisphere - Max Temp vs. Latitude Linear Regression',
                       'Max Temperature',
                       'Maximum Temperature (F)',
                       'lat_temp.png',
                       (40,70))
# Out:
# The r-squared is: -0.7282840292152654

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_hemisphere_df,
                       'Southern Hemisphere - Max Temp vs. Latitude Linear Regression',
                       'Max Temperature',
                       'Maximum Temperature (F)',
                       'lat_temp.png',
                       (-30,45))
# Out:
# The r-squared is: 0.7679040026640708

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_hemisphere_df,
                       'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression',
                       'Humidity',
                       'Humidity (%) ',
                       'lat_humidity.png',
                       (30,75))
# Out:
# The r-squared is: -0.11441370571790183

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_hemisphere_df,
                       'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression',
                       'Humidity',
                       'Humidity (%)',
                       'lat_humidity.png',
                       (-30,75))
# Out:
# The r-squared is: -0.03987249680685722

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_hemisphere_df,
                       'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression',
                       'Cloudiness',
                       'Cloudiness (%)',
                       'lat_cloudiness',
                       (40,60))
# Out:
# The r-squared is: -0.11909859273890164

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_hemisphere_df,
                       'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression',
                       'Cloudiness',
                       'Cloudiness (%)',
                       'lat_cloundiness.png',
                       (-40,50))
# Out:
# The r-squared is: -0.02796059757868486

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_hemisphere_df,
                       'Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression',
                       'Wind Speed',
                       'Wind Speed (mph)',
                       'lat_wind.png',
                       (30,4))
# Out:
# The r-squared is: 0.032291349740832656

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_hemisphere_df,
                       'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression',
                       'Wind Speed',
                       'Wind Speed (mph)',
                       'lat_wind.png',
                       (-30,4))
# Out:
# The r-squared is: -0.1546745882122554
